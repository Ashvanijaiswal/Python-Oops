# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('final_result.csv')
df.head()
# Out:
#    InvoiceNumber    CreatedTime  StoreID   PosID CustomerType PaymentMethod  \
# 0       51402977  1595688900348  STR7188  POS956        PRIME          CARD
# 1       51402977  1595688900348  STR7188  POS956        PRIME          CARD
# 2       51402977  1595688900348  STR7188  POS956        PRIME          CARD
# 3       51402977  1595688900348  STR7188  POS956        PRIME          CARD
# 4       91372973  1595688901219  STR8513  POS163        PRIME          CARD
#
#     DeliveryType       City           State  PinCode  ItemCode  \
# 0       TAKEAWAY        NaN             NaN      NaN       458
# 1       TAKEAWAY        NaN             NaN      NaN       283
# 2       TAKEAWAY        NaN             NaN      NaN       498
# 3       TAKEAWAY        NaN             NaN      NaN       523
# 4  HOME-DELIVERY  Shivapuri  Madhya Pradesh      NaN       413
#
#   ItemDescription  ItemPrice  ItemQty  TotalValue
# 0      Wine glass     1644.0        2      3288.0
# 1  Portable Lamps     2236.0        1      2236.0
# 2  Carving knifes     1424.0        2      2848.0
# 3  Oil-lamp clock     1371.0        2      2742.0
# 4       Slipcover     1896.0        1      1896.0

# %%
sns.lineplot(df.head(50), x="StoreID", y="TotalValue")
plt.show()

# %%
sns.boxplot(df.head(50), x="StoreID", y="TotalValue")
plt.show()

# %%
df[['StoreID','DeliveryType']].shape
# Out:
# (3990, 2)

# %%
df[]
